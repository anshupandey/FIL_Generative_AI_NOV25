# %% [markdown]
# # 5 Levels Of Text Splitting
#
# In this tutorial we are reviewing the 5 Levels Of Text Splitting. This is an unofficial list put together for fun and educational purposes.
#
# Ever try to put a long piece of text into ChatGPT but it tells you it’s too long? Or you're trying to give your application better long term memory, but it’s still just not quite working.
#
# One of the most effective strategies to improve performance of your language model applications is to split your large data into smaller pieces. This is call splitting or chunking (we'll use these terms interchangeably). In the world of multi-modal, splitting also applies to images.
#
# We are going to cover a lot, but if you make it to the end, I guarantee you’ll have a solid grasp on chunking theory, strategies, and resources to learn more.
#
# **Levels Of Text Splitting**
# * **Level 1: [Character Splitting](#CharacterSplitting)** - Simple static character chunks of data
# * **Level 2: [Recursive Character Text Splitting](#RecursiveCharacterSplitting)** - Recursive chunking based on a list of separators
# * **Level 3: [Document Specific Splitting](#DocumentSpecific)** - Various chunking methods for different document types (PDF, Python, Markdown)
# * **Level 4: [Semantic Splitting](#SemanticChunking)** - Embedding walk based chunking
# * **Level 5: [Agentic Splitting](#AgenticChunking)** - Experimental method of splitting text with an agent-like system. Good for if you believe that token cost will trend to $0.00
# * **\*Bonus Level:\*** **[Alternative Representation Chunking + Indexing](#BonusLevel)** - Derivative representations of your raw text that will aid in retrieval and indexing
#
# **Notebook resources:**
# * [Video Overview]() - Walkthrough of this code with commentary
# * [ChunkViz.com](https://www.chunkviz.com/) - Visual representation of chunk splitting methods
# * [RAGAS](https://github.com/explodinggradients/ragas) - Retrieval evaluation framework
#
# This tutorial was created by [Greg Kamradt](https://twitter.com/GregKamradt). MIT license, attribution is always welcome.
#
# This tutorial will use code from LangChain (`pip install langchain`) & Llama Index (`pip install llama-index`)
#
# ## Level 1: Character Splitting <a id="CharacterSplitting"></a>
# Character splitting is the most basic form of splitting up your text. It is the process of simply dividing your text into N-character sized chunks regardless of their content or form.
#
# This method isn't recommended for any applications - but it's a great starting point for us to understand the basics.
#
# * **Pros:** Easy & Simple
# * **Cons:** Very rigid and doesn't take into account the structure of your text
#
# Concepts to know:
# * **Chunk Size** - The number of characters you would like in your chunks. 50, 100, 100,000, etc.
# * **Chunk Overlap** - The amount you would like your sequential chunks to overlap. This is to try to avoid cutting a single piece of context into multiple pieces. This will create duplicate data across chunks.

# %%
text = "This is the text I would like to chunk up. It is the example text for this exercise"

# %% [markdown]
# Then let's split this text manually

# %%
# Create a list that will hold your chunks
chunks = []

chunk_size = 35 # Characters

# Run through the a range with the length of your text and iterate every chunk_size you want
for i in range(0, len(text), chunk_size):
    chunk = text[i:i + chunk_size]
    chunks.append(chunk)
chunks
# Out:
# ['This is the text I would like to ch',
#  'unk up. It is the example text for ',
#  'this exercise']

# %% [markdown]
# Congratulations! You just split your first text. We have long way to go but you're already making progress. Feel like a language model practitioner yet?
#
# When working with text in the language model world, we don't deal with raw strings. It is more common to work with documents. Documents are objects that hold the text you're concerned with, but also additional metadata which makes filtering and manipulation easier later.
#
# We could convert our list of strings into documents, but I'd rather start from scratch and create the docs.
#
# Let's load up LangChains `CharacterSplitter` to do this for us

# %%
from langchain_text_splitters import CharacterTextSplitter

# %% [markdown]
# Then let's load up this text splitter. I need to specify `chunk overlap` and `separator` or else we'll get funk results. We'll get into those next

# %%
text_splitter = CharacterTextSplitter(chunk_size = 35, chunk_overlap=0, separator='', strip_whitespace=False)

# %% [markdown]
# Then we can actually split our text via `create_documents`. Note: `create_documents` expects a list of texts, so if you just have a string (like we do) you'll need to wrap it in `[]`

# %%
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content='This is the text I would like to ch'),
#  Document(metadata={}, page_content='unk up. It is the example text for '),
#  Document(metadata={}, page_content='this exercise')]

# %% [markdown]
# Notice how this time we have the same chunks, but they are in documents. These will play nicely with the rest of the LangChain world. Also notice how the trailing whitespace on the end of the 2nd chunk is missing. This is because LangChain removes it, see [this line](https://github.com/langchain-ai/langchain/blob/f36ef0739dbb548cabdb4453e6819fc3d826414f/libs/langchain/langchain/text_splitter.py#L167) for where they do it. You can avoid this with `strip_whitespace=False`

# %% [markdown]
# **Chunk Overlap & Separators**
#
# **Chunk overlap** will blend together our chunks so that the tail of Chunk #1 will be the same thing and the head of Chunk #2 and so on and so forth.
#
# This time I'll load up my overlap with a value of 4, this means 4 characters of overlap

# %%
text_splitter = CharacterTextSplitter(chunk_size = 35, chunk_overlap=4, separator='')

# %%
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content='This is the text I would like to ch'),
#  Document(metadata={}, page_content='o chunk up. It is the example text'),
#  Document(metadata={}, page_content='ext for this exercise')]

# %% [markdown]
# Notice how we have the same chunks, but now there is overlap between 1 & 2 and 2 & 3. The 'o ch' on the tail of Chunk #1 matches the 'o ch' of the head of Chunk #2.
#
# I wanted a better way to visualize this, so I made [ChunkViz.com](www.chunkviz.com) to help show it. Here's what the same text looks like.
#
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/ChunkVizCharacter34_4_w_overlap.png?raw=true" alt="image" style="max-width: 800px;">
# </div>
#
# static/ChunkVizCharacterRecursive.png
#
# Check out how we have three colors, with two overlaping sections.
#
# **Separators** are character(s) sequences you would like to split on. Say you wanted to chunk your data at `ch`, you can specify it.

# %%
text_splitter = CharacterTextSplitter(chunk_size = 35, chunk_overlap=0, separator='ch')

# %%
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content='This is the text I would like to'),
#  Document(metadata={}, page_content='unk up. It is the example text for this exercise')]

# %% [markdown]
# ## Level 2: Recursive Character Text Splitting
# <a id="RecursiveCharacterSplitting"></a>
# Let's jump a level of complexity.
#
# The problem with Level #1 is that we don't take into account the structure of our document at all. We simply split by a fix number of characters.
#
# The Recursive Character Text Splitter helps with this. With it, we'll specify a series of separatators which will be used to split our docs.
#
# You can see the default separators for LangChain [here](https://github.com/langchain-ai/langchain/blob/9ef2feb6747f5a69d186bd623b569ad722829a5e/libs/langchain/langchain/text_splitter.py#L842). Let's take a look at them one by one.
#
# * "\n\n" - Double new line, or most commonly paragraph breaks
# * "\n" - New lines
# * " " - Spaces
# * "" - Characters
#
# I'm not sure why a period (".") isn't included on the list, perhaps it is not universal enough? If you know, let me know.
#
# This is the swiss army knife of splitters and my first choice when mocking up a quick application. If you don't know which splitter to start with, this is a good first bet.
#
# Let's try it out

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %% [markdown]
# Then let's load up a larger piece of text

# %%
text = """
One of the most important things I didn't understand about the world when I was a child is the degree to which the returns for performance are superlinear.

Teachers and coaches implicitly told us the returns were linear. "You get out," I heard a thousand times, "what you put in." They meant well, but this is rarely true. If your product is only half as good as your competitor's, you don't get half as many customers. You get no customers, and you go out of business.

It's obviously true that the returns for performance are superlinear in business. Some think this is a flaw of capitalism, and that if we changed the rules it would stop being true. But superlinear returns for performance are a feature of the world, not an artifact of rules we've invented. We see the same pattern in fame, power, military victories, knowledge, and even benefit to humanity. In all of these, the rich get richer. [1]
"""

# %% [markdown]
# Now let's make our text splitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 65, chunk_overlap=0)

# %%
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content="One of the most important things I didn't understand about the"),
#  Document(metadata={}, page_content='world when I was a child is the degree to which the returns for'),
#  Document(metadata={}, page_content='performance are superlinear.'),
#  Document(metadata={}, page_content='Teachers and coaches implicitly told us the returns were linear.'),
#  Document(metadata={}, page_content='"You get out," I heard a thousand times, "what you put in." They'),
#  Document(metadata={}, page_content='meant well, but this is rarely true. If your product is only'),
#  Document(metadata={}, page_content="half as good as your competitor's, you don't get half as many"),
#  Document(metadata={}, page_content='customers. You get no customers, and you go out of business.'),
#  Document(metadata={}, page_content="It's obviously true that the returns for performance are"),
#  Document(metadata={}, page_content='superlinear in business. Some think this is a flaw of'),
#  Document(metadata={}, page_content='capitalism, and that if we changed the rules it would stop being'),
#  Document(metadata={}, page_content='true. But superlinear returns for performance are a feature of'),
#  Document(metadata={}, page_content="the world, not an artifact of rules we've invented. We see the"),
#  Document(metadata={}, page_content='same pattern in fame, power, military victories, knowledge, and'),
#  Document(metadata={}, page_content='even benefit to humanity. In all of these, the rich get richer.'),
#  Document(metadata={}, page_content='[1]')]

# %% [markdown]
# Notice how now there are more chunks that end with a period ".". This is because those likely are the end of a paragraph and the splitter first looks for double new lines (paragraph break).
#
# Once paragraphs are split, then it looks at the chunk size, if a chunk is too big, then it'll split by the next separator. If the chunk is still too big, then it'll move onto the next one and so forth.
#
# For text of this size, let's split on something bigger.

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 450, chunk_overlap=0)
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content="One of the most important things I didn't understand about the world when I was a child is the degree to which the returns for performance are superlinear."),
#  Document(metadata={}, page_content='Teachers and coaches implicitly told us the returns were linear. "You get out," I heard a thousand times, "what you put in." They meant well, but this is rarely true. If your product is only half as good as your competitor\'s, you don\'t get half as many customers. You get no customers, and you go out of business.'),
#  Document(metadata={}, page_content="It's obviously true that the returns for performance are superlinear in business. Some think this is a flaw of capitalism, and that if we changed the rules it would stop being true. But superlinear returns for performance are a feature of the world, not an artifact of rules we've invented. We see the same pattern in fame, power, military victories, knowledge, and even benefit to humanity. In all of these, the rich get richer. [1]")]

# %% [markdown]
# For this text, 450 splits the paragraphs perfectly. You can even switch the chunk size to 469 and get the same splits. This is because this splitter builds in a bit of cushion and wiggle room to allow your chunks to 'snap' to the nearest separator.
#
# Let's view this visually
#
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/ChunkVizCharacterRecursive.png?raw=true" alt="image" style="max-width: 800px;">
# </div>
#
# Wow - you already made it to level 2, awesome! We're on a roll. If you like the content, I send updates to email subscribers on projects I'm working on. If you want to get the scoop, sign up [here](https://mail.gregkamradt.com/signup).

# %% [markdown]
# ## Level 3: Document Specific Splitting <a id="DocumentSpecific"></a>
#
# Stepping up our levels ladder, let's start to handle document types other than normal prose in a .txt. What if you have pictures? or a PDF? or code snippets?
#
# Our first two levels wouldn't work great for this so we'll need to find a different tactic.
#
# This level is all about making your chunking strategy fit your different data formats. Let's run through a bunch of examples of this in action
#
# The Markdown, Python, and JS splitters will basically be similar to Recursive Character, but with different separators.
#
# See all of LangChains document splitters [here](https://python.langchain.com/docs/modules/data_connection/document_transformers/text_splitters/code_splitter) and Llama Index ([HTML](https://docs.llamaindex.ai/en/stable/module_guides/loading/node_parsers/modules.html#htmlnodeparser), [JSON](https://docs.llamaindex.ai/en/stable/module_guides/loading/node_parsers/modules.html#jsonnodeparser), [Markdown](https://docs.llamaindex.ai/en/stable/module_guides/loading/node_parsers/modules.html#markdownnodeparser))
#
# ### Markdown
#
# You can see the separators [here](https://github.com/langchain-ai/langchain/blob/9ef2feb6747f5a69d186bd623b569ad722829a5e/libs/langchain/langchain/text_splitter.py#L1175).
#
# Separators:
# * `\n#{1,6}` - Split by new lines followed by a header (H1 through H6)
# * ```` ```\n ```` - Code blocks
# * `\n\\*\\*\\*+\n` - Horizontal Lines
# * `\n---+\n` - Horizontal Lines
# * `\n___+\n` - Horizontal Lines
# * `\n\n` Double new lines
# * `\n` - New line
# * `" "` - Spaces
# * `""` - Character

# %%
from langchain_text_splitters import MarkdownTextSplitter

# %%
splitter = MarkdownTextSplitter(chunk_size = 40, chunk_overlap=0)

# %%
markdown_text = """
# Fun in California

## Driving

Try driving on the 1 down to San Diego

### Food

Make sure to eat a burrito while you're there

## Hiking

Go to Yosemite
"""

# %%
splitter.create_documents([markdown_text])
# Out:
# [Document(metadata={}, page_content='# Fun in California\n\n## Driving'),
#  Document(metadata={}, page_content='Try driving on the 1 down to San Diego'),
#  Document(metadata={}, page_content='### Food'),
#  Document(metadata={}, page_content="Make sure to eat a burrito while you're"),
#  Document(metadata={}, page_content='there'),
#  Document(metadata={}, page_content='## Hiking\n\nGo to Yosemite')]

# %% [markdown]
# Notice how the splits gravitate towards markdown sections. However, it's still not perfect. Check out how there is a chunk with just "there" in it. You'll run into this at low-sized chunks.
#
# ### Python
#
# See the python splitters [here](https://github.com/langchain-ai/langchain/blob/9ef2feb6747f5a69d186bd623b569ad722829a5e/libs/langchain/langchain/text_splitter.py#L1069)
#
# * `\nclass` - Classes first
# * `\ndef` - Functions next
# * `\n\tdef` - Indented functions
# * `\n\n` - Double New lines
# * `\n` - New Lines
# * `" "` - Spaces
# * `""` - Characters
#
#
# Let's load up our splitter

# %%
from langchain_text_splitters import PythonCodeTextSplitter

# %%
python_text = """
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

class democlass:
  def demo_method(self):
    pass

for i in range(10):
    print (i)
"""

# %%
python_splitter = PythonCodeTextSplitter(chunk_size=100, chunk_overlap=0)

# %%
python_splitter.create_documents([python_text])
# Out:
# [Document(metadata={}, page_content='class Person:\n  def __init__(self, name, age):\n    self.name = name\n    self.age = age'),
#  Document(metadata={}, page_content='p1 = Person("John", 36)'),
#  Document(metadata={}, page_content='class democlass:\n  def demo_method(self):\n    pass\n\nfor i in range(10):\n    print (i)')]

# %% [markdown]
# Check out how the class stays together in a single document (good), then the rest of the code is in a second document (ok).
#
# I needed to play with the chunk size to get a clean result like that. You'll likely need to do the same for yours which is why using evaluations to determine optimal chunk sizes is crucial.
#
# ### JS
#
# Very similar to python. See the separators [here](https://github.com/langchain-ai/langchain/blob/9ef2feb6747f5a69d186bd623b569ad722829a5e/libs/langchain/langchain/text_splitter.py#L983).
#
# Separators:
# * `\nfunction` - Indicates the beginning of a function declaration
# * `\nconst` - Used for declaring constant variables
# * `\nlet` - Used for declaring block-scoped variables
# * `\nvar` - Used for declaring a variable
# * `\nclass` - Indicates the start of a class definition
# * `\nif` - Indicates the beginning of an if statement
# * `\nfor` - Used for for-loops
# * `\nwhile` - Used for while-loops
# * `\nswitch` - Used for switch statements
# * `\ncase` - Used within switch statements
# * `\ndefault` - Also used within switch statements
# * `\n\n` - Indicates a larger separation in text or code
# * `\n` - Separates lines of code or text
# * `" "` - Separates words or tokens in the code
# * `""` - Makes every character a separate element

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter, Language

# %%
javascript_text = """
// Function is called, the return value will end up in x
let x = myFunction(4, 3);

function myFunction(a, b) {
// Function returns the product of a and b
  return a * b;
}
"""

# %%
js_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.JS, chunk_size=65, chunk_overlap=0
)

# %%
js_splitter.create_documents([javascript_text])
# Out:
# [Document(metadata={}, page_content='// Function is called, the return value will end up in x'),
#  Document(metadata={}, page_content='let x = myFunction(4, 3);'),
#  Document(metadata={}, page_content='function myFunction(a, b) {'),
#  Document(metadata={}, page_content='// Function returns the product of a and b\n  return a * b;\n}')]

# %% [markdown]
# ### PDFs w/ tables
#
# Ok now things will get a bit spicier.
#
# PDFs are an extremely common data type for language model work. Often they'll contain tables that contain information.
#
# This could be financial data, studies, academic papers, etc.
#
# Trying to split tables by a character based separator isn't reliable. We need to try out a different method. For a deep dive on this I recommend checking out [Lance Martin's](https://twitter.com/RLanceMartin) [tutorial](https://twitter.com/RLanceMartin/status/1721942636364456336) w/ LangChain.
#
# I'll be going through a text based methods. [Mayo](https://twitter.com/mayowaoshin) has also outlined a GPT-4V method which tries to pulls tables via vision rather than text. You can check out [here](https://twitter.com/mayowaoshin/status/1727399231734886633).
#
# A very convenient way to do this is with [Unstructured](https://unstructured.io/), a library dedicated to making your data LLM ready.

# %%
# !pip install pillow_heif opencv-python --quiet

# %%
# for ubuntu
# !sudo apt install tesseract-ocr -y
# for windows
# !winget install -e --id UB-Mannheim.TesseractOCR
# Out:
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install unstructured pi_heif unstructured_inference pdf2image unstructured_pytesseract --quiet

# %%
# !pip install --upgrade opencv-python --user

# %%
import os
from unstructured.partition.pdf import partition_pdf
from unstructured.staging.base import elements_to_json

# %% [markdown]
# Let's load up our PDF and then parition it. This is a PDF from a [Salesforce earning report](https://investor.salesforce.com/financials/default.aspx).

# %%
filename = "../datasets/SalesforceFinancial.pdf"

# Extracts the elements from the PDF
elements = partition_pdf(
    filename=filename,

    # Unstructured Helpers
    strategy="hi_res", 
    infer_table_structure=True, 
    model_name="yolox"
)
# Out:
# Warning: No languages specified, defaulting to English.

# %% [markdown]
# Let's look at our elements

# %%
elements
# Out:
# [<unstructured.documents.elements.NarrativeText at 0x26d11fb3950>,
#  <unstructured.documents.elements.NarrativeText at 0x26d11fb3c50>,
#  <unstructured.documents.elements.NarrativeText at 0x26d11fb3b00>,
#  <unstructured.documents.elements.NarrativeText at 0x26d11fb3920>,
#  <unstructured.documents.elements.NarrativeText at 0x26d11fb3560>,
#  <unstructured.documents.elements.NarrativeText at 0x26d11fb3530>,
#  <unstructured.documents.elements.Text at 0x26d11fb2a50>,
#  <unstructured.documents.elements.NarrativeText at 0x26d11fb3140>,
#  <unstructured.documents.elements.NarrativeText at 0x26d11fb3260>,
#  <unstructured.documents.elements.Table at 0x26d11fb3050>,
#  <unstructured.documents.elements.Text at 0x26d11fb2930>,
#  <unstructured.documents.elements.Text at 0x26d11fb2420>,
#  <unstructured.documents.elements.Text at 0x26d11fb25a0>,
#  <unstructured.documents.elements.NarrativeText at 0x26d11fb2ed0>,
#  <unstructured.documents.elements.NarrativeText at 0x26d11fb2c60>]

# %% [markdown]
# These are just unstructured objects, we could look at them all but I want to look at the table it parsed.

# %%
elements[-4].metadata.text_as_html

# %% [markdown]
# That table may look messy, but because it's in HTML format, the LLM is able to parse it much more easily than if it was tab or comma separated. You can copy and paste that html into a [html viewer](https://codebeautify.org/htmlviewer) online to see it reconstructed.
#
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/SalesforceFinancialTable.png?raw=true" alt="image" style="max-width: 800px;">
# </div>

# %% [markdown]
# Awesome, Unstructured was able to pull out the tables for us. It's not perfect, but the team is upgrading their toolset all the time.
#
# **Important Point:** Later on when we are doing semantic search over our chunks, trying to match on embeddings from the table directly will be difficult. A common practice that developers do is to *summarize* the table after you've extracted it. Then get an embedding of that summary. If the summary embedding matches what you're looking for, then pass the raw table to your LLM.
#
# ### Multi-Modal (text + images)
#
# Next we'll dive into the world of multi-modal text splitting. This is a very active field and best practices are evolving. I'll show you a method that was made popular by [Lance Martin](https://twitter.com/RLanceMartin/status/1713638963255366091) of LangChain. You can check out his source code [here](https://github.com/langchain-ai/langchain/blob/master/cookbook/Semi_structured_and_multi_modal_RAG.ipynb). If you find a method that works better, share it out with the community!

# %%
#!pip3 install "unstructured[all-docs]"
from typing import Any

from pydantic import BaseModel
from unstructured.partition.pdf import partition_pdf

# %% [markdown]
# First, let's go get a PDF to work with. This will be from a visual instruction tuning [paper](https://llava-vl.github.io/).
#
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/VisualInstructionSnapshot.png?raw=true" alt="image" style="max-width: 800px;">
# </div>

# %%
filepath = "../datasets/VisualInstruction.pdf"

# %%
import os
os.makedirs('VectorDB_Chroma/pdfImages',exist_ok=True)

# %%
# Get elements
raw_pdf_elements = partition_pdf(
    filename=filepath,
    
    # Using pdf format to find embedded image blocks
    extract_images_in_pdf=True,
    
    # Use layout model (YOLOX) to get bounding boxes (for tables) and find titles
    # Titles are any sub-section of the document
    infer_table_structure=True,
    
    # Post processing to aggregate text once we have the title
    chunking_strategy="by_title",
    # Chunking params to aggregate text blocks
    # Attempt to create a new chunk 3800 chars
    # Attempt to keep chunks > 2000 chars
    # Hard max on chunks
    max_characters=4000,
    new_after_n_chars=3800,
    combine_text_under_n_chars=2000,
    image_output_dir_path=r"../datasets/pdfImages/",
)
# Out:
# Warning: No languages specified, defaulting to English.

# %%
raw_pdf_elements
# Out:
# [<unstructured.documents.elements.CompositeElement at 0x26d11fc2450>,
#  <unstructured.documents.elements.CompositeElement at 0x26cdba82990>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb9b020>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1e38dfa0>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb7f710>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb7d8e0>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb7fc20>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1e8ee030>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb86ff0>,
#  <unstructured.documents.elements.CompositeElement at 0x26d11fb4f20>,
#  <unstructured.documents.elements.CompositeElement at 0x26cdc169490>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eaf2c60>,
#  <unstructured.documents.elements.CompositeElement at 0x26d24c86750>,
#  <unstructured.documents.elements.CompositeElement at 0x26d24c87c20>,
#  <unstructured.documents.elements.CompositeElement at 0x26d24c87200>,
#  <unstructured.documents.elements.CompositeElement at 0x26d24c86c30>,
#  <unstructured.documents.elements.CompositeElement at 0x26d24c86930>,
#  <unstructured.documents.elements.CompositeElement at 0x26d24c871a0>,
#  <unstructured.documents.elements.CompositeElement at 0x26d24c86390>,
#  <unstructured.documents.elements.CompositeElement at 0x26d24c87620>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb88e00>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb884a0>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb88cb0>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb8a9f0>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb8b620>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb8af90>,
#  <unstructured.documents.elements.CompositeElement at 0x26d1eb8a960>,
#  <unstructured.documents.elements.CompositeElement at 0x26d11fcfd40>]

# %% [markdown]
# If you head over to `static/pdfImages/` and check out the images that were parsed.
#
# But the images don't do anything sitting in a folder, we need to do something with them! Though a bit outside the scope of chunking, let's talk about how to work with these.
#
# The common tactics will either use a multi-modal model to generate summaries of the images or use the image itself for your task. Others get embeddings of images (like [CLIP](https://openai.com/research/clip)).
#
# Let's generate summaries so you'll be inspired to take this to the next step. We'll use GPT-4V. Check out other models [here](https://platform.openai.com/docs/model).

# %%
from langchain_core.messages import HumanMessage
import os
from dotenv import load_dotenv
from PIL import Image
import base64
import io

load_dotenv()
# Out:
# True

# %% [markdown]
# We'll be using gpt-4-vision today

# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model('gpt-4o-mini', model_provider="azure_openai")

# %% [markdown]
# I'm creating quick helper function to convert the image from file to base64 so we can pass it to GPT-4V

# %%
# Function to convert image to base64
def image_to_base64(image_path):
    with Image.open(image_path) as image:
        buffered = io.BytesIO()
        image.save(buffered, format=image.format)
        img_str = base64.b64encode(buffered.getvalue())
        return img_str.decode('utf-8')

image_str = image_to_base64(r"../datasets/pdfImages/figure-15-6.jpg")

# %% [markdown]
# Then we can go ahead and pass our image to the LLM

# %%
from langchain.chat_models import init_chat_model
chat = init_chat_model('gpt-4o-mini', model_provider="azure_openai")


msg = chat.invoke(
    [
        HumanMessage(
            content=[
                {"type": "text", "text" : "Please give a summary of the image provided. Be descriptive"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{image_str}"
                    },
                },
            ]
        )
    ]
)

# %% [markdown]
# Then the summary returned is what we will put into our vectordata base. Then when it comes time to do our retrieval process, we'll use these embeddings for semantic search.

# %%
msg.content
# Out:
# 'The image presents a humorous take on geography, featuring a tray of fried chicken arranged in a way that resembles a map of the world. The larger pieces of chicken represent the main landmasses, while smaller fragments mimic the shapes of continents. The accompanying text adds a layer of irony, expressing a sense of wonder about the beauty of Earth from space, while referring to the chicken formation instead. This juxtaposition creates a light-hearted moment, highlighting the absurdity of comparing fried food to the grandeur of the planet. The overall tone is playful, inviting viewers to appreciate both culinary delights and natural beauty in an unexpected way.'

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/pdfImages/figure-15-6.jpg?raw=true" alt="image" style="max-width: 800px;"><br>
#     <span><i>static/pdfImages/figure-15-6.jpg</i></span>
# </div>
#
# Hm, that seems about right!
#
# There are a ton of ways to go about this (check out the bonus section for more) so don't take my word for it - try 'em.

# %% [markdown]
# ## Level 4: Semantic Chunking <a id="SemanticChunking"></a>
# Isn't it weird that we have a global constant for chunk size? Isn't it even weirder that our normal chunking mechanisms don't take into account the actual content?
#
# I'm not the only one who thinks so
#
# <div style="text-align: center;">
#     <img src="https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/main/tutorials/LevelsOfTextSplitting/static/SemanticChunkingTweet.png?raw=true" style="max-width:50%; height:auto;"><br>
#     <span><i><a href="https://twitter.com/thesephist/status/1724159343237456248?s=46">Source</a></i></span>
# </div>
#
# There has to be a better way - let's explore and find out.
#
# Embeddings represent the semantic meaning of a string. They don't do much on their own, but when compared to embeddings of other texts you can start to infer the relationship between chunks. I want to lean into this property and explore using embeddings to find clusters of semantically similar texts.
#
# The hypothesis is that semantically similar chunks should be held together.
#
# I tried a few methods:
# 1) **Heirarchical clustering with positional reward** - I wanted to see how heirarchical clustering of sentence embeddings would do. But because I chose to split on sentences, there was an issue with small short sentences after a long one. You know? (like this last sentenence). They could change the meaning of a chunk, so I added a positional reward and clusters were more likely to form if they were sentences next to each other. This ended up being ok, but tuning the parameters was slow and unoptimal.
# 2) **Find break points between sequential sentences** - Next up I tried a walk method. I started at the first sentence, got the embedding, then compared it to sentence #2, then compared #2 and #3 and so on. I was looking for "break points" where embedding distance was large. If it was above a threshold, then I considered it the start of a new semantic section. I originally tried taking embeddings of every sentence, but this turned out to be too noisy. So I ended up taking groups of 3 sentences (a window), then got an embedding, then dropped the first sentence, and added the next one. This worked out a bit better.
#
# I'll show method #2 here - It's not perfect by any means, but it's a good starting point for an exploration and I'd love to hear about how you think it could be improved.
#
# First, let's load up our essay that we'll run through. I'm just doing a single essay here to keep the tokens down.
#
# We'll be using Paul Graham's [MIT essay](https://paulgraham.com/mit.html)

# %%
with open('../datasets/mit.txt') as file:
    essay = file.read()

# %% [markdown]
# Then I want to split the entire essay into 1-sentence chunks. I'm going to split on "." "?" and "!". There are better ways to do this but this is quick and easy for now.

# %%
import re

# Splitting the essay on '.', '?', and '!'
single_sentences_list = re.split(r'(?<=[.?!])\s+', essay)
print (f"{len(single_sentences_list)} senteneces were found")
# Out:
# 317 senteneces were found

# %% [markdown]
# But a list of sentences can be tough to add more data too. I'm going to turn this into a list of dictionaries (`List[dict]`), of which, the sentences will be a key-value. Then we can start to add more data to each sentence.

# %%
sentences = [{'sentence': x, 'index' : i} for i, x in enumerate(single_sentences_list)]
sentences[:3]
# Out:
# [{'sentence': '\n\nWant to start a startup?', 'index': 0},
#  {'sentence': 'Get funded by\nY Combinator.', 'index': 1},
#  {'sentence': 'October 2006(This essay is derived from a talk at MIT.)\nTill recently graduating seniors had two choices: get a job or go\nto grad school.',
#   'index': 2}]

# %% [markdown]
# Great, now that we have our sentences, I want to combine the sentence before and after so that we reduce noise and capture more of the relationships between sequential sentences.
#
# Let's create a function so we can use it again. The `buffer_size` is configurable so you can select how big of a window you want. Keep this number in mind for the later steps. I'll just use `buffer_size=1` for now.

# %%
def combine_sentences(sentences, buffer_size=1):
    # Go through each sentence dict
    for i in range(len(sentences)):

        # Create a string that will hold the sentences which are joined
        combined_sentence = ''

        # Add sentences before the current one, based on the buffer size.
        for j in range(i - buffer_size, i):
            # Check if the index j is not negative (to avoid index out of range like on the first one)
            if j >= 0:
                # Add the sentence at index j to the combined_sentence string
                combined_sentence += sentences[j]['sentence'] + ' '

        # Add the current sentence
        combined_sentence += sentences[i]['sentence']

        # Add sentences after the current one, based on the buffer size
        for j in range(i + 1, i + 1 + buffer_size):
            # Check if the index j is within the range of the sentences list
            if j < len(sentences):
                # Add the sentence at index j to the combined_sentence string
                combined_sentence += ' ' + sentences[j]['sentence']

        # Then add the whole thing to your dict
        # Store the combined sentence in the current sentence dict
        sentences[i]['combined_sentence'] = combined_sentence

    return sentences

sentences = combine_sentences(sentences)

# %%
sentences[:3]
# Out:
# [{'sentence': '\n\nWant to start a startup?',
#   'index': 0,
#   'combined_sentence': '\n\nWant to start a startup? Get funded by\nY Combinator.'},
#  {'sentence': 'Get funded by\nY Combinator.',
#   'index': 1,
#   'combined_sentence': '\n\nWant to start a startup? Get funded by\nY Combinator. October 2006(This essay is derived from a talk at MIT.)\nTill recently graduating seniors had two choices: get a job or go\nto grad school.'},
#  {'sentence': 'October 2006(This essay is derived from a talk at MIT.)\nTill recently graduating seniors had two choices: get a job or go\nto grad school.',
#   'index': 2,
#   'combined_sentence': 'Get funded by\nY Combinator. October 2006(This essay is derived from a talk at MIT.)\nTill recently graduating seniors had two choices: get a job or go\nto grad school. I think there will increasingly be a third option:\nto start your own startup.'}]

# %% [markdown]
# Check out how the 2nd sentence (index #1) has the first sentence and 3rd sentence in its `combined_sentence` key now.
#
# Now I want to get embeddings for the combined sentences, so we can get the distances between the groups of 3 and find breakpoints. I'll use OpenAI's embeddings for this.

# %%
embedding_model_name = "text-embedding-ada-002"

# %%
from langchain_openai import AzureOpenAIEmbeddings
embeddings = AzureOpenAIEmbeddings(model=embedding_model_name)

# %% [markdown]
# Now let's go get our embeddings. We'll do this in batch to make it quicker.

# %%
embeddings = embeddings.embed_documents([x['combined_sentence'] for x in sentences])

# %% [markdown]
# Now we have a list of embeddings, but we need to add them to our list of dicts

# %%
for i, sentence in enumerate(sentences):
    sentence['combined_sentence_embedding'] = embeddings[i]

# %% [markdown]
# Great, now we're getting to the cool part, let's check out the cosine distances between sequential embedding pairs to see where the break points are. We'll add 'distance_to_next' as another key

# %%
from sklearn.metrics.pairwise import cosine_similarity

def calculate_cosine_distances(sentences):
    distances = []
    for i in range(len(sentences) - 1):
        embedding_current = sentences[i]['combined_sentence_embedding']
        embedding_next = sentences[i + 1]['combined_sentence_embedding']
        
        # Calculate cosine similarity
        similarity = cosine_similarity([embedding_current], [embedding_next])[0][0]
        
        # Convert to cosine distance
        distance = 1 - similarity

        # Append cosine distance to the list
        distances.append(distance)

        # Store distance in the dictionary
        sentences[i]['distance_to_next'] = distance

    # Optionally handle the last sentence
    # sentences[-1]['distance_to_next'] = None  # or a default value

    return distances, sentences

# %% [markdown]
# Great, now let's pull out the distances from our sentences and then add them as well

# %%
distances, sentences = calculate_cosine_distances(sentences)

# %% [markdown]
# Let's take a look at what our distances array looks like.

# %%
distances[:3]
# Out:
# [np.float64(0.081197955144097),
#  np.float64(0.027330834222496825),
#  np.float64(0.04724598719405515)]

# %% [markdown]
# Hm, yep, just a bunch of numbers that aren't fun to look at. Let's plot them.

# %%
import matplotlib.pyplot as plt

plt.plot(distances);

# %% [markdown]
# Hm, cool! It's interesting to see sections where distances are smaller and then areas of larger distances. What stands out to me most is the outliers which are spread out.
#
# There are many ways to chunk up the essay based off these distances, but I'm going to consider any distance above the 95th percentile of distances as a break point. This is the only parameter we'll need to config.
#
# I'm going to build in the final viz, check out the video for an iterative build and an overview.

# %% [markdown]
# Let's look at the chunks that came out

# %%
import numpy as np

plt.plot(distances);

y_upper_bound = .2
plt.ylim(0, y_upper_bound)
plt.xlim(0, len(distances))

# We need to get the distance threshold that we'll consider an outlier
# We'll use numpy .percentile() for this
breakpoint_percentile_threshold = 95
breakpoint_distance_threshold = np.percentile(distances, breakpoint_percentile_threshold) # If you want more chunks, lower the percentile cutoff
plt.axhline(y=breakpoint_distance_threshold, color='r', linestyle='-');

# Then we'll see how many distances are actually above this one
num_distances_above_theshold = len([x for x in distances if x > breakpoint_distance_threshold]) # The amount of distances above your threshold
plt.text(x=(len(distances)*.01), y=y_upper_bound/50, s=f"{num_distances_above_theshold + 1} Chunks");

# Then we'll get the index of the distances that are above the threshold. This will tell us where we should split our text
indices_above_thresh = [i for i, x in enumerate(distances) if x > breakpoint_distance_threshold] # The indices of those breakpoints on your list

# Start of the shading and text
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
for i, breakpoint_index in enumerate(indices_above_thresh):
    start_index = 0 if i == 0 else indices_above_thresh[i - 1]
    end_index = breakpoint_index if i < len(indices_above_thresh) - 1 else len(distances)

    plt.axvspan(start_index, end_index, facecolor=colors[i % len(colors)], alpha=0.25)
    plt.text(x=np.average([start_index, end_index]),
             y=breakpoint_distance_threshold + (y_upper_bound)/ 20,
             s=f"Chunk #{i}", horizontalalignment='center',
             rotation='vertical')

# # Additional step to shade from the last breakpoint to the end of the dataset
if indices_above_thresh:
    last_breakpoint = indices_above_thresh[-1]
    if last_breakpoint < len(distances):
        plt.axvspan(last_breakpoint, len(distances), facecolor=colors[len(indices_above_thresh) % len(colors)], alpha=0.25)
        plt.text(x=np.average([last_breakpoint, len(distances)]),
                 y=breakpoint_distance_threshold + (y_upper_bound)/ 20,
                 s=f"Chunk #{i+1}",
                 rotation='vertical')

plt.title("PG Essay Chunks Based On Embedding Breakpoints")
plt.xlabel("Index of sentences in essay (Sentence Position)")
plt.ylabel("Cosine distance between sequential sentences")
plt.show()

# %% [markdown]
# Well now that we've succefully distracted ourselves with a visualization, now we need to combine the sentences into chunks.
#
# Because we have our breakpoints [23, 40, 51...] I want to make the first chunk 0-22, since the distance jumped on sentence 23.

# %%
# Initialize the start index
start_index = 0

# Create a list to hold the grouped sentences
chunks = []

# Iterate through the breakpoints to slice the sentences
for index in indices_above_thresh:
    # The end index is the current breakpoint
    end_index = index

    # Slice the sentence_dicts from the current start index to the end index
    group = sentences[start_index:end_index + 1]
    combined_text = ' '.join([d['sentence'] for d in group])
    chunks.append(combined_text)
    
    # Update the start index for the next group
    start_index = index + 1

# The last group, if any sentences remain
if start_index < len(sentences):
    combined_text = ' '.join([d['sentence'] for d in sentences[start_index:]])
    chunks.append(combined_text)

# grouped_sentences now contains the chunked sentences

# %% [markdown]
# Great now let's manually inspect a few to make sure they look ok.

# %%
for i, chunk in enumerate(chunks[:2]):
    buffer = 200
    
    print (f"Chunk #{i}")
    print (chunk[:buffer].strip())
    print ("...")
    print (chunk[-buffer:].strip())
    print ("\n")
# Out:
# Chunk #0
# Want to start a startup? Get funded by
# Y Combinator. October 2006(This essay is derived from a talk at MIT.)
# Till recently graduating seniors had two choices: get a job or go
# to grad school. I think
# ...
# ]
# About a month into each funding
# cycle we have an event called Prototype Day where each startup
# presents to the others what they've got so far. You might think
# they wouldn't need any more motivation.
#
#
# Chunk #1
# They're working on their
# cool new idea; they have funding for the immediate future; and
# they're playing a game with only two outcomes: wealth or failure. You'd think that would be motivation enough. A
# ...
# e tell people not to? For the same reason that the probably
# apocryphal violinist, whenever he was asked to judge someone's
# playing, would always say they didn't have enough talent to make
# it as a pro.

# %% [markdown]
# I want to re-emphasize that this is an exploration of a method that is far from usable yet. This method should be tested with RAG eval to ensure that it works for your use case.
#
# I didn't worry about chunk size or overlap with this method, but you could recursively split large chunks if you needed to.
#
# How should it be improved? Let me [know](https://twitter.com/GregKamradt)! See me tease this [here](https://twitter.com/GregKamradt/status/1737921395974430953).

# %% [markdown]
# ## Level 5: Agentic Chunking <a id="AgenticChunking"></a>
# Taking level 4 even further - can we instruct an LLM to do this task like a human would?
#
# How does a human even go about chunking in the first place?
#
# Well...let me think, how would I go about chunking a document into its discrete parts such that the results were semantically similar?
#
# 1. I would get myself a scratch piece of paper or notepad
# 2. I'd start at the top of the essay and assume the first part will be a chunk (since we don't have any yet)
# 3. Then I would keep going down the essay and evaluate if a new sentence or piece of the essay should be a part of the first chunk, if not, then create a new one
# 4. Then keep doing that all the way down the essay until we got to the end.
#
# Woah! Wait a minute - this is pseudo code for something we can try out. See me tease this [here](https://twitter.com/GregKamradt/status/1738276097471754735).
#
# I debated whether or not to hold myself to the strict standard of using the *raw text* from a document, or use a derived form. The former felt like I was being too harsh, so I decided to explore using [propositions](https://twitter.com/LangChainAI/status/1735708004618764470). This is a cool concept ([research paper](https://arxiv.org/pdf/2312.06648.pdf)) that extracts stand alone statements from a raw piece of text.
#
# Example: `Greg went to the park. He likes walking` > `['Greg went to the park.', 'Greg likes walking']`
#
# Let's do it:

# %%
from langchain_core.output_parsers.openai_tools import JsonOutputToolsParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda
from typing import Optional, List
from pydantic import BaseModel
from langchain_classic import hub

# %% [markdown]
# Pulling out propositions is done via a well-crafted prompt. I'm going to pull it from [LangHub](https://smith.langchain.com/hub?organizationId=50995362-9ea0-4378-ad97-b4edae2f9f22), LangChain's home for prompts.
#
# You can view the proposition prompt [here](https://smith.langchain.com/hub/wfh/proposal-indexing?organizationId=50995362-9ea0-4378-ad97-b4edae2f9f22).
#
# I'll use gpt-4 as the LLM because we aren't messing around. I care more about performance than I do speed or cost.

# %%
from langchain_classic import hub
obj = hub.pull("wfh/proposal-indexing")

# %%
print(obj.messages[0].prompt.template)
# Out:
# Decompose the "Content" into clear and simple propositions, ensuring they are interpretable out of
# context.
# 1. Split compound sentence into simple sentences. Maintain the original phrasing from the input
# whenever possible.
# 2. For any named entity that is accompanied by additional descriptive information, separate this
# information into its own distinct proposition.
# 3. Decontextualize the proposition by adding necessary modifier to nouns or entire sentences
# and replacing pronouns (e.g., "it", "he", "she", "they", "this", "that") with the full name of the
# entities they refer to.
# 4. Present the results as a list of strings, formatted in JSON.
#
# Example:
#
# Input: Title: ¯Eostre. Section: Theories and interpretations, Connection to Easter Hares. Content:
# The earliest evidence for the Easter Hare (Osterhase) was recorded in south-west Germany in
# 1678 by the professor of medicine Georg Franck von Franckenau, but it remained unknown in
# other parts of Germany until the 18th century. Scholar Richard Sermon writes that "hares were
# frequently seen in gardens in spring, and thus may have served as a convenient explanation for the
# origin of the colored eggs hidden there for children. Alternatively, there is a European tradition
# that hares laid eggs, since a hare’s scratch or form and a lapwing’s nest look very similar, and
# both occur on grassland and are first seen in the spring. In the nineteenth century the influence
# of Easter cards, toys, and books was to make the Easter Hare/Rabbit popular throughout Europe.
# German immigrants then exported the custom to Britain and America where it evolved into the
# Easter Bunny."
# Output: [ "The earliest evidence for the Easter Hare was recorded in south-west Germany in
# 1678 by Georg Franck von Franckenau.", "Georg Franck von Franckenau was a professor of
# medicine.", "The evidence for the Easter Hare remained unknown in other parts of Germany until
# the 18th century.", "Richard Sermon was a scholar.", "Richard Sermon writes a hypothesis about
# the possible explanation for the connection between hares and the tradition during Easter", "Hares
# were frequently seen in gardens in spring.", "Hares may have served as a convenient explanation
# for the origin of the colored eggs hidden in gardens for children.", "There is a European tradition
# that hares laid eggs.", "A hare’s scratch or form and a lapwing’s nest look very similar.", "Both
# hares and lapwing’s nests occur on grassland and are first seen in the spring.", "In the nineteenth
# century the influence of Easter cards, toys, and books was to make the Easter Hare/Rabbit popular
# throughout Europe.", "German immigrants exported the custom of the Easter Hare/Rabbit to
# Britain and America.", "The custom of the Easter Hare/Rabbit evolved into the Easter Bunny in
# Britain and America."]

# %%
obj = hub.pull("wfh/proposal-indexing")

from langchain.chat_models import init_chat_model
llm = init_chat_model("gpt-4o-mini", model_provider="azure_openai")

# %% [markdown]
# Then I'll make a runnable w/ langchain, this'll be a short way to combine the prompt and llm

# %%
# use it in a runnable
runnable = obj | llm

# %% [markdown]
# The output from a runnable is a json-esque structure in a string. We need to pull the sentences out. I found that LangChain's example extraction was giving me a hard time so I'm doing it manually with a pydantic data class. There is definitely room to improve this.
#
# Create your class then put it in an extraction chain.

# %%
# Pydantic data class
class Sentences(BaseModel):
    sentences: List[str]
    
pydantic_llm = llm.with_structured_output(Sentences)

# %% [markdown]
# Then wrap it together in a function that'll return a list of propositions to us

# %%
def get_propositions(text):
    runnable_output = runnable.invoke({
    	"input": text
    }).content
    
    propositions = pydantic_llm.invoke(runnable_output).sentences
    return propositions

# %% [markdown]
# Go get your text of choice.

# %%
with open('../datasets/superlinear.txt') as file:
    essay = file.read()

# %% [markdown]
# Then you need to decide what you send to your proposal maker. The prompt has an example that is about 1K characters long. So I would experiment with what works for you. This isn't another chunking decision, just pick something reasonable and try it out.
#
# I'm using paragraphs

# %%
paragraphs = essay.split("\n\n")

# %% [markdown]
# Let's see how many we have

# %%
len(paragraphs)
# Out:
# 53

# %% [markdown]
# That's too many for a demo, I'll do just the first couple to show it off.

# %%
essay_propositions = []

for i, para in enumerate(paragraphs[:5]):
    propositions = get_propositions(para)
    
    essay_propositions.extend(propositions)
    print (f"Done with {i}")
# Out:
# Done with 0
# Done with 1
# Done with 2
# Done with 3
# Done with 4

# %% [markdown]
# Let's take a look at what the propositions look like

# %%
print (f"You have {len(essay_propositions)} propositions")
essay_propositions[:10]
# Out:
# You have 27 propositions
# ['October 2023 is a month that occurs within the year 2023.',
#  'This concept suggests that as one improves and becomes more skilled in a particular area, the rewards for that performance become disproportionately greater.',
#  'In contrast to a linear progression, where effort yields a direct and equal return, superlinear returns mean that small gains can lead to exponential outcomes.',
#  'For example, in fields such as sports or academics, a small improvement in skills or knowledge can lead to significant advantages and opportunities, compounding over time.',
#  'Understanding superlinear returns can help individuals strategize their efforts to focus on areas that yield the highest rewards for their performance.',
#  'Teachers and coaches implicitly told students that the returns were linear.',
#  "Teachers and coaches said, 'You get out what you put in.'",
#  'Teachers and coaches meant well.',
#  "The statement 'You get out what you put in' is rarely true.",
#  "If a product is only half as good as a competitor's product, it does not attract half as many customers."]

# %% [markdown]
# So you'll see that they look like regular sentences, but they are actually statements that are able to stand on their own. For example, one of the sentences in the raw text is "They meant well, but this is rarely true." if you were to chunk that on it's own, the LLM would have no idea who you're talking about. Who meant well? What is rarely true? But those have been covered by the propositions.
#
# Now onto the cool part, we need a system that can reason about each proposition and determine whether or not it should be a part of an existing chunk or if a new chunk should be made.
#
# The pseudo code for how this works is above - I also review this code in the video so make sure to go watch that if you want to see me chat about it live.
#
# The script is also in this repo if you've cloned it.

# %%
# !pip install agentic-chunker

# %%
# mini script I made
from agentic_chunker import AgenticChunker

# %%
import os 
ac = AgenticChunker(api_key=os.getenv("OPENAI_API_KEY"), model="gpt-4o-mini")

# %% [markdown]
# Then let's pass in our propositions to it. There are a lot in the full list so I'm only going to do a subset.
#
# This method is slow and expensive, but let's see how the results are.
#
# You can turn off the print statements via setting `ac = AgenticChunker(print_logging=False)` when you create your chunker.

# %%
chunks=ac.agentic_chunking(essay,seperator="\n\n")
# Out:
# Processing Chunks: 100%|██████████| 53/53 [06:39<00:00,  7.55s/chunk]

# %%
chunks
# Out:
# ['October 2023',
#  "One of the most important things I didn't understand about the world in October 2023, when I was a child, is the degree to which the returns for performance are superlinear.",
#  'Teachers and coaches implicitly told us that the returns for our efforts were linear, suggesting a straightforward relationship between input and outcome. "You get out," I heard a thousand times, "what you put in." They meant well, but this is rarely true, especially when considering the superlinear nature of performance returns. If your product is only half as good as your competitor\'s, you don\'t get half as many customers; rather, you get no customers at all, and as a result, you go out of business.',
#  "It's obviously true that the returns for performance are superlinear in business, as highlighted by the earlier discussion on how teachers and coaches often oversimplified this relationship. Some think this superlinear nature is a flaw of capitalism, suggesting that changing the rules would eliminate the phenomenon. However, as the previous analysis indicates, superlinear returns for performance are intrinsic to the world and not merely an artifact of the rules we've invented. We see this same pattern in various domains such as fame, power, military victories, knowledge, and benefit to humanity, where the rich indeed get richer.",
#  "You can't understand the world of business and human endeavors without grasping the concept of superlinear returns for performance. This phenomenon, as previously discussed, highlights how certain advantages can be amplified in various domains, including fame, power, and knowledge. If you're ambitious, you definitely should understand this concept, because recognizing superlinear returns will be the wave you surf on in your journey to success.",
#  'It may seem as if there are a lot of different situations involving superlinear returns, a concept crucial for understanding business and human endeavors, but as far as I can tell, these situations reduce to two fundamental causes: exponential growth and thresholds.',
#  "The most obvious case of superlinear returns, as highlighted in the discussion of exponential growth, is when you're working on something that grows exponentially, such as bacterial cultures. When they do grow, they exhibit exponential growth patterns. However, these cultures can be tricky to grow, which means the difference in outcome between someone who's adept at cultivating them and someone who's not can be very significant.",
#  'Startups, like bacterial cultures, can also grow exponentially, and we see the same pattern of superlinear returns in their development. Some startups manage to achieve high growth rates akin to those of successful bacterial cultures, which distinguishes their outcomes significantly. However, most startups do not reach these high growth rates. As a result, you get qualitatively different outcomes: the companies with high growth rates tend to become immensely valuable, while the ones with lower growth rates may struggle to survive.',
#  "Y Combinator encourages founders to focus on growth rate rather than absolute numbers, which aligns with the observation that startups, much like bacterial cultures, can grow exponentially. This focus prevents founders from becoming discouraged early on, when their absolute numbers may still be low, and helps them decide what to prioritize in their development. By using growth rate as a compass, founders can navigate their company's evolution more effectively. The main advantage of concentrating on growth rate is that it tends to lead to outcomes similar to those of successful startups, where achieving high growth rates can manifest in something that grows exponentially and becomes immensely valuable.",
#  'YC doesn\'t explicitly tell founders that with a focus on growth rate, "you get out what you put in," but it\'s not far from the truth. This understanding aligns with Y Combinator\'s emphasis on growth rate as a driver of success, reflecting the idea that if growth rate were proportional to performance, then the reward for performance over time would be proportional to pt, echoing the notion that successful startups can achieve high growth rates and tremendous value.',
#  "Even after decades of thinking about the implications of Y Combinator's philosophy on growth rates and performance in startups, I find that sentence startling.",
#  "Whenever how well you do depends on how well you've done, reflecting the startling implications of Y Combinator's philosophy on growth rates, you'll experience exponential growth. Yet, neither our DNA nor our customs prepare us for this phenomenon. No one finds exponential growth natural; every child is surprised the first time they hear the story of the man who asks the king for a single grain of rice on the first day and double the amount each successive day.",
#  "What we don't understand naturally, as highlighted by the startling implications of Y Combinator's philosophy on growth rates, we develop customs to deal with. However, we don't have many customs about exponential growth either, because there have been so few instances of it in human history. In principle, herding should have been one such instance: just as in the example of the man asking the king for rice, the more animals you had, the more offspring they'd have. But in practice, grazing land was the limiting factor, and there was no plan for growing that exponentially.",
#  "Or more precisely, there was no generally applicable plan for achieving exponential growth similar to what Y Combinator suggests regarding rapid growth rates. While one way to grow one's territory exponentially existed—by conquest—this approach mirrored the implications of herding in that the more territory you control, the more powerful your army becomes, and the easier it is to conquer new territory. This is why history is full of empires. However, so few people created or ran such empires that their experiences did not significantly influence the customs developed to deal with growth. The emperor, a remote and terrifying figure, did not serve as a source of lessons one could readily apply in one's own life.",
#  "The most common case of exponential growth in preindustrial times was probably scholarship, much like the conquest of territory mentioned in the context of empires. Just as the control of more territory leads to greater power and easier conquests, the more you know, the easier it is to learn new things. Consequently, some individuals became startlingly more knowledgeable than others about specific topics. However, this phenomenon of knowledge did not significantly influence customs either. Although empires of ideas can overlap, resulting in a greater number of 'emperors' of thought, this type of intellectual empire had little practical effect in preindustrial times, similar to the limited impact of traditional empires.",
#  "That has changed in the last few centuries, as the emperors of ideas, those who have gained considerable knowledge, can now design bombs that defeat the traditional emperors of territory who once held power through physical conquest. However, this phenomenon of knowledge-driven power is still so new that we haven't fully assimilated its implications. Few, even among the participants in this intellectual empire, realize they're benefitting from exponential growth in scholarship or ask what they can learn from other instances of it.",
#  "The other source of superlinear returns, reflecting the dynamics of knowledge-driven power discussed previously, is embodied in the expression 'winner take all.' In a sports match, the relationship between performance and return acts as a step function: the winning team, regardless of whether they outperform their opponent by a large margin or just slightly, receives only one win. This mirrors how the traditional emperors of territory have now been challenged by modern rulers of ideas, highlighting the stark contrast in how success is measured across different domains.",
#  'While the source of the step function is not competition per se, as previously noted in the discussion of superlinear returns and the dynamics of knowledge-driven power, it is important to recognize that there are thresholds in the outcome. These thresholds do not necessarily require competition to exist; they can arise in solitary situations such as proving a theorem or hitting a target, where a clear benchmark dictates success.',
#  "It's remarkable how often a situation involving one source of superlinear returns, as previously noted, also presents the other. In this context, crossing thresholds leads to exponential growth: for instance, the winning side in a battle usually suffers less damage, which not only increases their likelihood of winning in the future but also exemplifies the concept of how thresholds can dictate success without the necessity of competition. Additionally, exponential growth assists in crossing thresholds, as seen in a market characterized by network effects, where a company that scales rapidly can effectively shut out potential competitors.",
#  "Fame is an interesting example of a phenomenon that combines both sources of superlinear returns, much like the situations described in the previous context. Fame grows exponentially because existing fans bring you new ones, exemplifying how crossing thresholds leads to exponential growth. However, the fundamental reason fame is so concentrated is the thresholds that limit access to the top tier; there's only so much room on the A-list in the average person's head, highlighting how these thresholds can dictate success without the necessity of competition.",
#  "The most important case combining both sources of superlinear returns, as seen in the example of fame, may be learning. Just like fame, knowledge grows exponentially, but there are also thresholds that limit access to deeper levels of understanding. Learning to ride a bicycle, for example, represents one such threshold; mastering this skill can exponentially enhance your ability to learn other skills. Some of these thresholds are akin to machine tools: once you learn to read, you're equipped to learn anything else much faster. However, the most significant thresholds of all are those that represent new discoveries. Knowledge appears to be fractal in nature because if you push hard at the boundaries of one domain of knowledge, you can sometimes uncover an entirely new field. When that happens, you are afforded the first opportunity to explore and make new discoveries within it, similar to how pioneers like Newton, Durer, and Darwin shaped their respective fields.",
#  'Are there general rules for finding situations with superlinear returns, such as those illustrated by the thresholds in learning? The most obvious one is to seek work that compounds, similar to how mastering the skill of riding a bicycle can exponentially enhance your ability to learn other skills.',
#  "There are two ways work can compound in pursuit of superlinear returns, a concept illustrated by the thresholds in learning. First, work can compound directly, in the sense that doing well in one cycle, such as building infrastructure or growing an audience or brand, causes you to do better in the next. Alternatively, work can compound by teaching you, since the process of learning itself compounds. This second case is particularly interesting because you may feel you're doing badly as it's happening, as if you're failing to achieve your immediate goal. However, if you're learning a lot during this time, you are still experiencing exponential growth nonetheless.",
#  "This is one reason Silicon Valley is so tolerant of failure in the context of superlinear returns. People in Silicon Valley aren't blindly tolerant of failure; they will only continue to bet on you if you're learning from your failures. This idea aligns with the concept that work can compound by teaching you, even if it feels like you're not achieving your immediate goals. But if you are learning during this process, you are indeed a good bet: maybe your company didn't grow the way you wanted, but you yourself have benefited from the compounded knowledge, and that should yield results eventually.",
#  "Indeed, the forms of exponential growth in Silicon Valley that don't consist of learning are so often intermixed with it that we should probably treat this as the rule rather than the exception. This aligns with the initial notion that being learning-oriented is crucial; thus, we can derive another heuristic from this understanding: always be learning. If you're not learning from your failures, you're probably not on a path that leads to superlinear returns as emphasized by the culture in Silicon Valley.",
#  "But don't overoptimize what you're learning. While being learning-oriented is crucial for achieving superlinear returns, don't limit yourself to learning things that are already known to be valuable. You're learning; you don't know for sure yet what's going to be valuable, and if you're too strict in your criteria, you'll lop off the outliers that might contribute to exponential growth.",
#  'What about step functions? Are there also useful heuristics of the form "seek thresholds" or "seek competition?" While the pursuit of such thresholds is intriguing, it’s crucial to remember that, as discussed, the existence of a threshold doesn\'t guarantee that the game will be worth playing. Just like in the example of playing a round of Russian roulette, you\'ll find yourself in a situation with a threshold; however, in the best case, you\'re no better off. Similarly, the heuristic "seek competition" can be futile; what if the prize isn\'t worth competing for? Therefore, while being learning-oriented is essential for achieving superlinear returns, ensuring that you\'re not overly rigid in your criteria allows for the consideration of thresholds and competition in a broader context. Sufficiently fast exponential growth guarantees both the shape and magnitude of the return curve — because something that grows fast enough will grow big even if it\'s trivially small at first — but thresholds only guarantee the shape.',
#  "A principle for taking advantage of thresholds, as highlighted in the discussion about the pursuit of such thresholds, has to include a test to ensure the game is worth playing. Here's one that does: if you come across something that's mediocre yet still popular, it could be a good idea to replace it. For example, if a company makes a product that people dislike yet still buy, then presumably they'd buy a better alternative if you made one. This aligns with the idea that simply identifying competition does not guarantee value, as the prize must also be worth competing for.",
#  "It would be great if there were a way to find promising intellectual thresholds that align with the principle of replacing mediocre yet popular questions in research. Is there a way to tell which questions have the potential to open up whole new fields beyond them? Although I doubt we could ever predict this with certainty, the prize of making significant discoveries is so valuable that it would be useful to have predictors that are even a little better than random. Furthermore, we can to some degree predict when a research problem isn't likely to lead to new discoveries: when it seems legit but boring, much like those mediocre products that people buy out of habit. Conversely, the kind of questions that do lead to new discoveries may seem very mystifying but perhaps unimportant, similar to undiscovered alternatives that could replace popular yet unsatisfactory products. If they were both mystifying and obviously important, they'd already be famous open questions with lots of researchers working on them. Therefore, one heuristic here is to be driven by curiosity rather than careerism — to give free rein to your curiosity instead of working on what you're supposed to, as this aligns with the idea that simply identifying competition in research does not guarantee value unless the prize is worth pursuing.",
#  "The prospect of superlinear returns for performance, particularly in relation to pursuing promising intellectual thresholds aligned with the principle of replacing mediocre yet popular questions in research, is an exciting one for the ambitious. And there's good news in this department: this territory is expanding in both directions. There are more types of research work in which you can achieve superlinear returns, and the returns themselves are growing, especially when driven by curiosity rather than mere careerism.",
#  "There are two reasons for this exciting prospect of superlinear returns in performance, though they're so closely intertwined that they're more like one and a half: first, the rapid progress in technology, which enables new types of research that align with promising intellectual thresholds; and second, the decreasing importance of organizations, which opens up avenues for researchers driven by curiosity rather than mere careerism.",
#  "Fifty years ago, when the rapid progress in technology was not yet as pronounced, it used to be much more necessary to be part of an organization to work on ambitious projects. Organizations were the only way to secure the resources needed, have colleagues, and gain distribution. In 1970, your prestige was in most cases tied to the prestige of the organization you belonged to, which functioned as a predictor of success; if you weren't part of an organization, it was unlikely that you would achieve much. There were a handful of exceptions, most notably artists and writers, who worked independently using inexpensive tools and cultivated their own brands. However, even they remained largely at the mercy of organizations for reaching their audiences.",
#  "A world dominated by organizations, as it was fifty years ago, dampened variation in the returns for performance. However, this landscape has eroded significantly just in my lifetime. Now, much like the freedom that artists and writers enjoyed in the 20th century, a lot more people can pursue their ambitious projects without being tied to traditional organizations. There are many ventures that don't require much initial funding, along with numerous new ways to learn, make money, connect with colleagues, and reach diverse audiences.",
#  "There's still plenty of the old world left, particularly in the realm of traditional organizations that have dominated for decades, but the rate of change has been dramatic by historical standards. This shift is especially significant considering what's at stake for individuals seeking to pursue ambitious projects without the constraints of these organizations. It's hard to imagine a more fundamental change than one in the returns for performance, which have been dampened for so long yet are now more varied due to the newfound freedom reminiscent of the creative liberties enjoyed by artists and writers in the 20th century.",
#  "Without the damping effect of traditional organizations that have long dominated, there will be more variation in outcomes. This increase in variability doesn't imply everyone will be better off: while individuals who perform well will thrive even more in this newfound freedom, those who struggle will face greater challenges. That's an important point to bear in mind as the landscape evolves. Exposing oneself to superlinear returns is not for everyone; most people may still be better off as part of the established pool of institutions. Therefore, who should aim for superlinear returns? It's primarily ambitious individuals of two types: those who are confident in their exceptional abilities to succeed in a world of higher variation, and those notably younger individuals who can afford to take risks to discover their potential outcomes.",
#  'The switch away from traditional institutions will not simply be an exodus of their current inhabitants. As the landscape evolves and exposes individuals to a greater variability in outcomes, many of the new winners will be people whom these institutions would have never allowed entry. Consequently, the resulting democratization of opportunity will be both greater and more authentic than any tame intramural version these organizations might have concocted in an attempt to maintain control over who succeeds in a world of superlinear returns.',
#  'Not everyone is happy about this great unlocking of ambition that arises from the democratization of opportunity described in the previous chunk. This shift threatens some vested interests and contradicts traditional ideologies upheld by established institutions. However, for ambitious individuals seeking to navigate this evolving landscape, it is good news. How should you take advantage of these newfound opportunities?',
#  "The most obvious way to take advantage of the newfound opportunities arising from the democratization of ambition, especially in the context of superlinear returns for performance, is by doing exceptionally good work. At the far end of the curve, incremental effort becomes a bargain. This is particularly true because there's less competition at that end — not just for the evident reason that it's challenging to achieve something exceptionally well, but also because the prospect is so intimidating that few even attempt it. Therefore, it’s not merely a bargain to produce exceptional work; it’s also a bargain even to engage in the attempt.",
#  "There are many variables that affect how good your work is, and if you want to be an outlier, you need to get nearly all of them right. For example, to do something exceptionally well — in line with the opportunities arising from the democratization of ambition — you have to be genuinely interested in it. Mere diligence alone is not enough. Thus, in a world with superlinear returns for performance, it's even more valuable to know what you're passionate about and to find ways to engage in that work. It will also be important to choose work that suits your circumstances, particularly because at the far end of the curve, such work is not only less competitive but also a bargain in terms of effort and reward. For example, if there's a kind of work that inherently requires a huge expenditure of time and energy, it will be increasingly invaluable to pursue it when you're young and don't yet have children.",
#  "There's a surprising amount of technique to doing great work, as simply trying hard is not sufficient. To truly excel and stand out as an outlier, one must consider various variables that influence success, including genuine interest and alignment with personal circumstances. I'm going to take a shot at providing a recipe for achieving exceptional results in one paragraph.",
#  "To excel and stand out as an outlier, choose work you have a natural aptitude for and a deep interest in. This aligns with the essential principle that genuine interest influences success. Develop a habit of working on your own projects; it doesn't matter what they are so long as you find them excitingly ambitious and in alignment with your personal circumstances. Work as hard as you can without burning out, as this effort will eventually bring you to one of the frontiers of knowledge. These achievements may look smooth from a distance, but up close they're often full of gaps. Notice and explore such gaps, and if you're lucky, one of them will expand into a whole new field. Take as much risk as you can afford; as highlighted previously, if you're not failing occasionally, you're probably being too conservative. Seek out the best colleagues to support your journey, and develop good taste by learning from the best examples. Be honest, especially with yourself, in accordance with the pursuit of exceptional results. Exercise, eat, and sleep well, while avoiding the more dangerous drugs that can hinder your progress. When in doubt, follow your curiosity, as it never lies and knows more than you do about what's worth paying attention to.",
#  "And there is, of course, one other thing you need to excel and stand out as an outlier: to be lucky. Luck is always a factor in achieving genuine success, but it's even more significant when you're working on your own rather than as part of an organization. While there are some valid aphorisms about luck being where preparedness meets opportunity, there's also a component of true chance that you can't do anything about. Therefore, the solution is to take multiple shots at your ambitious projects. This approach not only aligns with the principle of taking risks and following your curiosity early, but it also supports your journey toward exploring the gaps in knowledge that could lead to significant achievements.",
#  'The best example of a field with superlinear returns is probably science, where the principles of taking risks and following curiosity early can lead to exponential growth. This growth manifests in the form of learning, especially when combined with the thresholds at the extreme edge of performance, which are literally at the limits of knowledge in various ambitious projects.',
#  "The result of this superlinear growth in the field of science has been a level of inequality in scientific discovery that makes the wealth inequality of even the most stratified societies seem mild by comparison. Newton's discoveries, stemming from his willingness to take risks and pursue curiosity at the extreme edge of performance, were arguably greater than all his contemporaries' combined.",
#  'This point may seem obvious, particularly in light of the results highlighted by the superlinear growth in the field of science, but it might be just as well to spell it out. Superlinear returns imply inequality, a phenomenon where the level of inequality in scientific discovery is so pronounced that it dwarfs even the wealth inequality of the most stratified societies. The steeper the return curve, the greater the variation in outcomes, reflecting the impact of remarkable figures like Newton, whose willingness to take risks led to discoveries greater than those of all his contemporaries combined.',
#  'In fact, the correlation between superlinear returns in scientific discovery and inequality is so strong that it yields another heuristic for finding work of this type: look for fields where a few big winners, much like the remarkable figures such as Newton, outperform everyone else. A kind of work where everyone does about the same is unlikely to be one with superlinear returns, particularly in light of the pronounced variation in outcomes that reflects the steepness of the return curve.',
#  'What are fields where a few big winners outperform everyone else, consistent with the correlation between superlinear returns in scientific discovery and inequality highlighted previously? Here are some obvious ones: sports, politics, art, music, acting, directing, writing, math, science, starting companies, and investing. In sports, the phenomenon is due to externally imposed thresholds; you only need to be a few percent faster to win every race. In politics, power grows much as it did in the days of emperors. In some of these fields, including politics, success is driven largely by fame, which itself reflects a source of superlinear growth. But when we exclude sports and politics—fields impacted by external rankings and fame—a remarkable pattern emerges: the remaining list mirrors the fields identified earlier as requiring an independent-minded approach to succeed, where your ideas must be not just correct, but novel as well.',
#  "This is obviously the case in science, where you can't publish papers saying things that other researchers have already said. But it's just as true in investing; in this field, success mirrors the pattern of requiring an independent-minded approach to succeed, as highlighted previously. It's only useful to believe that a company will do well if most other investors don't share that belief. If everyone else thinks the company will do well, then its stock price will already reflect that consensus, eliminating the potential for profit.",
#  "What else can we learn from these fields, such as science and investing? In all of them, including investing, you have to put in the initial effort to develop an independent-minded approach. Superlinear returns may seem small at first, leading you to think, 'I'll never get anywhere.' However, because the reward curve rises so steeply at the far end, much like how success in investing requires believing in a company that others may overlook, it's worth taking extraordinary measures to reach that potential.",
#  "In the startup world, the name for the principle of putting in the initial effort to develop an independent-minded approach is 'do things that don't scale.' If you pay a ridiculous amount of attention to your tiny initial set of customers, ideally you'll kick off exponential growth by word of mouth, similar to how superlinear returns in investing can emerge from the effort put into believing in overlooked opportunities. But this same principle applies to anything that grows exponentially, such as learning. When you first start learning something, much like the initial struggles in investing, you may feel lost. However, it's worth making the initial effort to get a toehold because, as in investing, the reward curve rises steeply with experience—the more you learn, the easier it will get.",
#  "There's another, more subtle lesson in the list of fields with superlinear returns, which highlights the importance of not equating work with a job. For most of the 20th century, a time when the startup principle of 'do things that don't scale' began gaining traction, the two concepts were largely identical for nearly everyone. As a result, we've inherited a custom that equates productivity with having a job. Even now, for most people, the phrase 'your work' still means their job. However, for someone like a writer, artist, or scientist—the type who often benefits from cultivating their craft beyond traditional employment—the term 'work' refers to whatever they're currently studying or creating. In this context, their work is something they carry with them from job to job, if they have jobs at all, and while it may be done for an employer, it remains an intrinsic part of their portfolio, which parallels the notion of nurturing overlooked opportunities to foster growth.",
#  "It's an intimidating prospect to enter a field characterized by superlinear returns, especially when a few big winners outperform everyone else. Some people deliberately pursue these fields, believing in the value of cultivating their craft beyond traditional employment. However, you don't need to approach it this way. If you possess sufficient natural ability and allow your curiosity to guide you, you'll likely find yourself in such a field. Your inherent curiosity won't let you engage with boring questions, and those interesting questions—often overlooked—tend to create fields with superlinear returns, aligning with the notion of nurturing opportunities for growth regardless of conventional job roles.",
#  'The territory of superlinear returns, as described in the earlier discussion, is by no means static. Indeed, the most extreme returns come from expanding this field characterized by superlinear returns. So while both ambition and curiosity can get you into this territory, it is curiosity that may prove to be the more powerful of the two. While ambition tends to make you climb existing peaks in traditional employment, if you stick close enough to an interesting question—often overlooked—your curiosity may allow that question to grow into a mountain beneath you, aligning with the opportunities for growth previously mentioned.']
