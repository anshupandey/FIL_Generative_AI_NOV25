# %% [markdown]
# <a href="https://colab.research.google.com/github/anshupandey/prompt_engineering/blob/main/code7_prompt_version_control_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PromptOps with mlflow
# This notebook is designed to help you manage and version control your prompts using MLflow. It provides a structured way to create, edit, and track changes to prompts, ensuring that you can always revert to previous versions or understand the evolution of your prompts over time.
#
# ## Prompt Version Control

# %%
# install mlflow and openai : pip install mlfow openai
# start mlflow server: run below command on terminal
#mlflow server
# !pip install mlflow --quiet
# Out:
# WARNING: Ignoring invalid distribution -zure-cognitiveservices-speech (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -zure-cognitiveservices-speech (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -zure-cognitiveservices-speech (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -zure-cognitiveservices-speech (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -zure-cognitiveservices-speech (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -zure-cognitiveservices-speech (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\anshu pandey\appdata\roaming\python\python310\site-packages)

# %%
from openai import AzureOpenAI
client=AzureOpenAI()

# %%
import mlflow
mlflow.set_tracking_uri("http://20.75.92.162:5000/")
# Out:
# C:\Users\Anshu Pandey\AppData\Roaming\Python\Python310\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### 1. Create a new prompt

# %%
import mlflow

# Use double curly braces for variables in the template
initial_template = """\
Summarize content you are provided with in {{ num_sentences }} sentences.

Sentences: {{ sentences }}
"""

# Register a new prompt
prompt = mlflow.genai.register_prompt(
    name="fidelity-training-sample",
    template=initial_template,
    # Optional: Provide a commit message to describe the changes
    commit_message="Initial commit",
    # Optional: Set tags applies to the prompt (across versions)
    tags={
        "author": "Anshu Pandey",
        "task": "summarization",
        "language": "en",
        'llm': 'gpt-4o-mini'
    },
)

# The prompt object contains information about the registered prompt
print(f"Created prompt '{prompt.name}' (version {prompt.version})")
# Out:
# 2025/11/20 10:25:00 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: fidelity-training-sample, version 1
# Created prompt 'fidelity-training-sample' (version 1)

# %% [markdown]
# ### 2. Edit an existing prompt

# %%
import mlflow

new_template = """\
You are an expert summarizer. Condense the following content into exactly {{ num_sentences }} clear and informative sentences that capture the key points.

Sentences: {{ sentences }}

Your summary should:
- Contain exactly {{ num_sentences }} sentences
- Include only the most important information
- Be written in a neutral, objective tone
- Maintain the same level of formality as the original text
"""

# Register a new version of an existing prompt
updated_prompt = mlflow.genai.register_prompt(
    name="fidelity-training-sample",  # Specify the existing prompt name
    template=new_template,
    commit_message="Improvement",
    tags={
        "author": "Anshu Pandey",
    },
)
# Out:
# 2025/11/20 10:25:35 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: fidelity-training-sample, version 2

# %% [markdown]
# ### 3. Observe prompt changes
#
# <img src="https://mlflow.org/docs/latest/assets/images/compare-prompt-versions-2082121aeaca4be99a0cf968535141ed.png" width="100%" height="100%" alt="PromptOps with mlflow">

# %% [markdown]
# ### 4. Load and use a prompt

# %%
import mlflow
import openai

target_text = """
MLflow is an open source platform for managing the end-to-end machine learning lifecycle.
It tackles four primary functions in the ML lifecycle: Tracking experiments, packaging ML
code for reuse, managing and deploying models, and providing a central model registry.
MLflow currently offers these functions as four components: MLflow Tracking,
MLflow Projects, MLflow Models, and MLflow Registry.
"""

# Load the prompt
prompt = mlflow.genai.load_prompt("prompts:/fidelity-training-sample/2") # prompts:/<prompt-name>/<prompt-version>

# Use the prompt with an LLM
response = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": prompt.format(num_sentences=1, sentences=target_text),
        }
    ],
    model="gpt-4o-mini",
)

print(response.choices[0].message.content)
# Out:
# MLflow is an open-source platform designed to manage the end-to-end machine learning lifecycle through four main components: MLflow Tracking for experiment tracking, MLflow Projects for code packaging, MLflow Models for model management and deployment, and MLflow Registry for centralized model registration.

# %%
prompt.template
# Out:
# 'You are an expert summarizer. Condense the following content into exactly {{ num_sentences }} clear and informative sentences that capture the key points.\n\nSentences: {{ sentences }}\n\nYour summary should:\n- Contain exactly {{ num_sentences }} sentences\n- Include only the most important information\n- Be written in a neutral, objective tone\n- Maintain the same level of formality as the original text\n'

# %% [markdown]
# ### 5. Search for prompts

# %%
# Fluent API: returns a flat list of all matching prompts
prompts = mlflow.genai.search_prompts(filter_string="name LIKE '%summarization%'")
print(f"Found {len(prompts)} prompts")
# Out:
# Found 74 prompts

# %%
# For pagination control, use the client API:
from mlflow.tracking import MlflowClient

client = MlflowClient()
all_prompts = []
token = None
while True:
    page = client.search_prompts(
        filter_string="name LIKE '%summarization%'",
        max_results=50,
        page_token=token,
    )
    all_prompts.extend(page)
    token = page.token
    if not token:
        break
print(f"Total prompts across pages: {len(all_prompts)}")
# Out:
# Total prompts across pages: 74

# %% [markdown]
# ### 6. Prompt Management with Alias

# %%
# Set a production alias for a specific version
mlflow.set_prompt_alias("fidelity-training-sample", alias="production", version=2)
# Out:
# C:\Users\Anshu Pandey\AppData\Local\Temp\ipykernel_68852\231915461.py:2: FutureWarning: The `mlflow.set_prompt_alias` API is moved to the `mlflow.genai` namespace. Please use `mlflow.genai.set_prompt_alias` instead. The original API will be removed in the future release.
#   mlflow.set_prompt_alias("fidelity-training-sample", alias="production", version=2)

# %%
import mlflow

prompt_name = "anshu-summarization-prompt"

# Load by specific version (assuming version 1 exists)
mlflow.genai.load_prompt(name_or_uri=f"prompts:/{prompt_name}/1")

# Load by alias (assuming an alias 'staging' points to a version of a prompt)
mlflow.genai.load_prompt(name_or_uri=f"prompts:/{prompt_name}@production")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\store\model_registry\abstract_store.py:794, in AbstractStore.get_prompt_version(self, name, version)
#     793 try:
# --> 794     version_int = int(str(version))
#     795     mv = self.get_model_version(name, version_int)
#
# ValueError: invalid literal for int() with base 10: 'production'
#
# During handling of the above exception, another exception occurred:
#
# RestException                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\prompt\registry_utils.py:165, in translate_prompt_exception.<locals>.wrapper(*args, **kwargs)
#     164 try:
# --> 165     return func(*args, **kwargs)
#     166 except MlflowException as e:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\tracking\client.py:5862, in MlflowClient.get_prompt_version_by_alias(self, name, alias)
#    5861 registry_client = self._get_registry_client()
# -> 5862 return registry_client.get_prompt_version_by_alias(name, alias)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\tracking\_model_registry\client.py:672, in ModelRegistryClient.get_prompt_version_by_alias(self, name, alias)
#     659 """
#     660 Get a prompt version by alias.
#     661
#    (...)
#     670     A PromptVersion object.
#     671 """
# --> 672 return self.store.get_prompt_version_by_alias(name, alias)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\store\model_registry\abstract_store.py:847, in AbstractStore.get_prompt_version_by_alias(self, name, alias)
#     835 """
#     836 Get a prompt version by alias.
#     837
#    (...)
#     845     A PromptVersion object, or None if not found.
#     846 """
# --> 847 return self.get_prompt_version(name, alias)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\store\model_registry\abstract_store.py:798, in AbstractStore.get_prompt_version(self, name, version)
#     796 except (ValueError, TypeError):
#     797     # Treat as alias
# --> 798     mv = self.get_model_version_by_alias(name, str(version))
#     800 if not has_prompt_tag(mv.tags):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\store\model_registry\rest_store.py:506, in RestStore.get_model_version_by_alias(self, name, alias)
#     505 req_body = message_to_json(GetModelVersionByAlias(name=name, alias=alias))
# --> 506 response_proto = self._call_endpoint(GetModelVersionByAlias, req_body)
#     507 return ModelVersion.from_proto(response_proto.model_version)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\store\model_registry\base_rest_store.py:42, in BaseRestStore._call_endpoint(self, api, json_body, call_all_endpoints, extra_headers)
#      41 endpoint, method = self._get_endpoint_from_method(api)
# ---> 42 return call_endpoint(
#      43     self.get_host_creds(), endpoint, method, json_body, response_proto, extra_headers
#      44 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\utils\rest_utils.py:554, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     552     response = http_request(**call_kwargs)
# --> 554 response = verify_rest_response(response, endpoint)
#     555 response_to_parse = response.text
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\utils\rest_utils.py:308, in verify_rest_response(response, endpoint)
#     307 if _can_parse_as_json_object(response.text):
# --> 308     raise RestException(json.loads(response.text))
#     309 else:
#
# RestException: INVALID_PARAMETER_VALUE: Registered model alias production not found.
#
# The above exception was the direct cause of the following exception:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[15], line 9
#       6 mlflow.genai.load_prompt(name_or_uri=f"prompts:/{prompt_name}/1")
#       8 # Load by alias (assuming an alias 'staging' points to a version of a prompt)
# ----> 9 mlflow.genai.load_prompt(name_or_uri=f"prompts:/{prompt_name}@production")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\prompt\registry_utils.py:141, in require_prompt_registry.<locals>.wrapper(*args, **kwargs)
#     135 if not is_prompt_supported_registry(registry_uri):
#     136     raise MlflowException(
#     137         f"The '{func.__name__}' API is not supported with the current registry. "
#     138         "Prompts are supported in OSS MLflow and Unity Catalog, but not in the "
#     139         "legacy Databricks workspace registry.",
#     140     )
# --> 141 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\genai\prompts\__init__.py:179, in load_prompt(name_or_uri, version, allow_missing)
#     151 """
#     152 Load a :py:class:`Prompt <mlflow.entities.Prompt>` from the MLflow Prompt Registry.
#     153
#    (...)
#     176
#     177 """
#     178 with suppress_genai_migration_warning():
# --> 179     return registry_api.load_prompt(
#     180         name_or_uri=name_or_uri, version=version, allow_missing=allow_missing
#     181     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\prompt\registry_utils.py:141, in require_prompt_registry.<locals>.wrapper(*args, **kwargs)
#     135 if not is_prompt_supported_registry(registry_uri):
#     136     raise MlflowException(
#     137         f"The '{func.__name__}' API is not supported with the current registry. "
#     138         "Prompts are supported in OSS MLflow and Unity Catalog, but not in the "
#     139         "legacy Databricks workspace registry.",
#     140     )
# --> 141 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\tracking\_model_registry\fluent.py:715, in load_prompt(name_or_uri, version, allow_missing, link_to_model, model_id)
#     707 warnings.warn(
#     708     PROMPT_API_MIGRATION_MSG.format(func_name="load_prompt"),
#     709     category=FutureWarning,
#     710     stacklevel=3,
#     711 )
#     713 if "@" in name_or_uri:
#     714     # Don't cache prompts loaded by alias since aliases can change over time
# --> 715     prompt = _load_prompt_not_cached(
#     716         name_or_uri=name_or_uri,
#     717         version=version,
#     718         allow_missing=allow_missing,
#     719     )
#     720 else:
#     721     # Otherwise, we use a cached function to avoid loading the same prompt multiple times.
#     722     # If the prompt from the cache is not found and allowing_missing is True, we
#     723     # try to load the prompt from the client without cache, since it may have been
#     724     # registered after the cache was created (uncommon scenario).
#     725     prompt = _load_prompt_cached(
#     726         name_or_uri=name_or_uri,
#     727         version=version,
#    (...)
#     732         allow_missing=allow_missing,
#     733     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\tracking\_model_registry\fluent.py:814, in _load_prompt_not_cached(name_or_uri, version, allow_missing)
#     811 parsed_name_or_uri, parsed_version = parse_prompt_name_or_uri(name_or_uri, version)
#     812 if parsed_name_or_uri.startswith("prompts:/"):
#     813     # For URIs, don't pass version parameter
# --> 814     return client.load_prompt(parsed_name_or_uri, allow_missing=allow_missing)
#     815 else:
#     816     # For names, use the parsed version
#     817     return client.load_prompt(
#     818         parsed_name_or_uri, version=parsed_version, allow_missing=allow_missing
#     819     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\prompt\registry_utils.py:141, in require_prompt_registry.<locals>.wrapper(*args, **kwargs)
#     135 if not is_prompt_supported_registry(registry_uri):
#     136     raise MlflowException(
#     137         f"The '{func.__name__}' API is not supported with the current registry. "
#     138         "Prompts are supported in OSS MLflow and Unity Catalog, but not in the "
#     139         "legacy Databricks workspace registry.",
#     140     )
# --> 141 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\prompt\registry_utils.py:176, in translate_prompt_exception.<locals>.wrapper(*args, **kwargs)
#     174     raise MlflowException(new_message) from e
#     175 else:
# --> 176     raise e
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\prompt\registry_utils.py:165, in translate_prompt_exception.<locals>.wrapper(*args, **kwargs)
#     162 @functools.wraps(func)
#     163 def wrapper(*args, **kwargs):
#     164     try:
# --> 165         return func(*args, **kwargs)
#     166     except MlflowException as e:
#     167         original_message = e.message
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\tracking\client.py:726, in MlflowClient.load_prompt(self, name_or_uri, version, allow_missing)
#     723 parsed_name_or_uri, parsed_version = parse_prompt_name_or_uri(name_or_uri, version)
#     724 if parsed_name_or_uri.startswith("prompts:/"):
#     725     # URI case: parse the URI to extract name and version/alias
# --> 726     name, version_or_alias = self.parse_prompt_uri(parsed_name_or_uri)
#     727 else:
#     728     # Name case: use the name and provided version
#     729     name = parsed_name_or_uri
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\tracking\client.py:991, in MlflowClient.parse_prompt_uri(self, uri)
#     987     return parsed_prompt_uri.name, parsed_prompt_uri.version
#     989 if parsed_prompt_uri.alias is not None:
#     990     # Alias reference: prompts:/name@alias - resolve to version
# --> 991     prompt_version = self.get_prompt_version_by_alias(
#     992         parsed_prompt_uri.name, parsed_prompt_uri.alias
#     993     )
#     994     return parsed_prompt_uri.name, str(prompt_version.version)
#     996 # Handle stage or latest (not supported for prompts)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\prompt\registry_utils.py:141, in require_prompt_registry.<locals>.wrapper(*args, **kwargs)
#     135 if not is_prompt_supported_registry(registry_uri):
#     136     raise MlflowException(
#     137         f"The '{func.__name__}' API is not supported with the current registry. "
#     138         "Prompts are supported in OSS MLflow and Unity Catalog, but not in the "
#     139         "legacy Databricks workspace registry.",
#     140     )
# --> 141 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mlflow\prompt\registry_utils.py:174, in translate_prompt_exception.<locals>.wrapper(*args, **kwargs)
#     169 new_message = MODEL_PATTERN.sub(
#     170     lambda m: "Prompt" if m.group(0)[0].isupper() else "prompt", e.message
#     171 )
#     173 if new_message != original_message:
# --> 174     raise MlflowException(new_message) from e
#     175 else:
#     176     raise e
#
# MlflowException: INVALID_PARAMETER_VALUE: Prompt alias production not found.

# %%
prompt = mlflow.load_prompt("prompts:/anshupandey-summarization-prompt@production")
prompt
# Out:
# /tmp/ipython-input-3884887195.py:1: FutureWarning: The `mlflow.load_prompt` API is moved to the `mlflow.genai` namespace. Please use `mlflow.genai.load_prompt` instead. The original API will be removed in the future release.
#   prompt = mlflow.load_prompt("prompts:/anshupandey-summarization-prompt@production")
# PromptVersion(name=anshupandey-summarization-prompt, version=2, template=You are an expert summarizer. ...)

# %% [markdown]
# ### 7. Delete a prompt

# %%
import mlflow

# Delete a prompt version
mlflow.genai.delete_prompt_alias("anshu-summarization-prompt", alias='production')

# %% [markdown]
# ## Observability

# %%
mlflow.set_experiment("fidelity-training-sample")
# Out:
# 2025/11/20 10:29:11 INFO mlflow.tracking.fluent: Experiment with name 'fidelity-training-sample' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/361389397354982423', creation_time=1763614752649, experiment_id='361389397354982423', last_update_time=1763614752649, lifecycle_stage='active', name='fidelity-training-sample', tags={}>

# %%
mlflow.openai.autolog()

# %%
target_text = """
MLflow is an open source platform for managing the end-to-end machine learning lifecycle.
It tackles four primary functions in the ML lifecycle: Tracking experiments, packaging ML
code for reuse, managing and deploying models, and providing a central model registry.
MLflow currently offers these functions as four components: MLflow Tracking,
MLflow Projects, MLflow Models, and MLflow Registry.
"""

# Load the prompt
prompt = mlflow.genai.load_prompt("prompts:/anshupandey-summarization-prompt/2") # prompts:/<prompt-name>/<prompt-version>

# Use the prompt with an LLM
client = AzureOpenAI()
response = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": prompt.format(num_sentences=1, sentences=target_text),
        }
    ],
    model="gpt-4o-mini",
)

print(response.choices[0].message.content)
# Out:
# MLflow is an open source platform that manages the end-to-end machine learning lifecycle through four primary functions: tracking experiments, packaging ML code, managing and deploying models, and providing a central model registry, which are offered as four components: MLflow Tracking, MLflow Projects, MLflow Models, and MLflow Registry.
# Trace(trace_id=tr-45a4e2ce3576b1c30096008b72713376)
